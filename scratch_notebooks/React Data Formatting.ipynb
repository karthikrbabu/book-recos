# %% [markdown]
# # Data Formatting - React + Flask App
# ## 08/01/2020

# %% [markdown]
# The purpose of this notebook is to simply format and add a column to the data that we store for our recommender to look up books. We add a column called "normalized" which takes a books original title and lower cases it, while replacing all empty spaces with underscores.
#
# Because we are interacting with Python APIs via Flask Requests using query params, using clean normalized titles for book lookups is needed.

# %%
#Imports
import numpy as np
import pandas as pd

# %%
#Load Data
books = pd.read_csv('../data/parsed_data/ultimate_books.csv')
books_colors = pd.read_csv('../data/parsed_data/books_colors.csv')

# %%
#Print all the titles in alphabetical/lexographical order

titles = list(books["original_title"][0:500])
res = []
for book in titles:
    if type(book) == str:
        res.append(book)
res.sort(reverse=False)
res
# Out:
# [' The Fellowship of the Ring',
#  '11/22/63',
#  'A Brief History of Time: From the Big Bang to Black Holes',
#  'A Christmas Carol',
#  'A Clash of Kings',
#  'A Clockwork Orange',
#  'A Confederacy of Dunces',
#  'A Dance with Dragons',
#  'A Discovery of Witches',
#  'A Farewell to Arms',
#  'A Feast for Crows',
#  'A Game of Thrones',
#  'A Grief Observed',
#  'A Heartbreaking Work of Staggering Genius',
#  'A Light in the Attic',
#  'A Little Princess',
#  "A Midsummer Night's Dream",
#  'A Million Little Pieces',
#  'A Prayer for Owen Meany',
#  'A Storm of Swords',
#  'A Tale of Two Cities',
#  'A Thousand Splendid Suns',
#  'A Tree Grows In Brooklyn ',
#  'A Walk to Remember',
#  'A Wrinkle in Time',
#  'After You',
#  "Alice's Adventures in Wonderland",
#  'Allegiant',
#  'American Gods',
#  'American Psycho',
#  'An Abundance of Katherines',
#  'An Excellent conceited Tragedie of Romeo and Juliet',
#  'And The Mountains Echoed',
#  'Angels & Demons ',
#  'Animal Farm: A Fairy Story',
#  'Anna and the French Kiss',
#  'Artemis Fowl',
#  'Atlas Shrugged',
#  'Atonement',
#  'Bared to You',
#  'Batman: The Dark Knight Returns',
#  'Batman: Year One',
#  'Beautiful Creatures',
#  'Beautiful Disaster',
#  'Before I Fall',
#  'Before I Go to Sleep',
#  'Bel Canto',
#  'Beowulf',
#  'Big Little Lies',
#  'Blood Promise',
#  'Bossypants',
#  'Brave New World',
#  'Breakfast of Champions',
#  'Breaking Dawn',
#  'Bridge to Terabithia',
#  'Can You Keep a Secret?',
#  'Candide',
#  "Cat's Cradle",
#  'Catch-22',
#  'Catching Fire',
#  'Charlie and the Chocolate Factory',
#  "Charlotte's Web",
#  'Choke',
#  'Christine',
#  'Cien años de soledad',
#  'Cinder',
#  'City of Ashes',
#  'City of Bones',
#  'City of Fallen Angels',
#  'City of Glass',
#  'City of Lost Souls',
#  'Clockwork Angel',
#  'Clockwork Prince',
#  'Clockwork Princess',
#  'Cloud Atlas',
#  'Club Dead',
#  'Complete Harry Potter Boxed Set',
#  'Confessions of a Shopaholic',
#  'Coraline',
#  'Crescendo',
#  'Cujo',
#  'Cutting for Stone',
#  'Dark Lover',
#  'Dark Places',
#  'Darkly Dreaming Dexter',
#  'Das Parfum. Die Geschichte eines Mörders',
#  'Daughter of Smoke & Bone',
#  'Dead Until Dark',
#  'Dead to the World',
#  'Dear John',
#  'Defending Jacob',
#  'Delirium',
#  'Die Verwandlung',
#  'Digital Fortress',
#  'Divergent',
#  'Divine Secrets of the Ya-Ya Sisterhood',
#  'Do Androids Dream of Electric Sheep?',
#  'Dracula',
#  'Dragonfly in Amber',
#  'Dress Your Family in Corduroy and Denim',
#  'Dune',
#  'East of Eden  ',
#  "Eat, pray, love: one woman's search for everything across Italy, India and Indonesia",
#  'Eclipse',
#  'El amor en los tiempos del cólera',
#  'Eldest',
#  'Eleanor & Park',
#  'Ella Enchanted',
#  'Emma',
#  'En man som heter Ove',
#  "Ender's Game",
#  'Eragon',
#  'Evermore',
#  'Extremely Loud and Incredibly Close',
#  'Fahrenheit 451',
#  'Fall of Giants',
#  'Fallen',
#  'Fantastic Beasts and Where to Find Them',
#  'Fear and Loathing in Las Vegas: A Savage Journey to the Heart of the American Dream',
#  'Fifty Shades Darker',
#  'Fifty Shades Freed',
#  'Fifty Shades of Grey',
#  'Fight Club',
#  'Flickan som lekte med elden',
#  'Flowers for Algernon',
#  'For Whom the Bell Tolls',
#  'Foundation',
#  'Frankenstein; or, The Modern Prometheus',
#  'Franny and Zooey',
#  'Freakonomics: A Rogue Economist Explores the Hidden Side of Everything',
#  'Frostbite',
#  'Girl with a Pearl Earring',
#  'Go Ask Alice',
#  'Go Set a Watchman',
#  'Gone Girl',
#  'Gone with the Wind',
#  'Good Omens: The Nice and Accurate Prophecies of Agnes Nutter, Witch',
#  'Good in Bed',
#  'Graceling',
#  'Great Expectations',
#  'Green Eggs and Ham',
#  'Gulliver’s Travels',
#  'Guns, Germs, and Steel: The Fates of Human Societies',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Cursed Child, Parts One and Two',
#  'Harry Potter and the Deathly Hallows',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Half-Blood Prince',
#  'Harry Potter and the Order of the Phoenix',
#  "Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Prisoner of Azkaban',
#  'Heart of Darkness',
#  'Het Achterhuis: Dagboekbrieven 14 juni 1942 - 1 augustus 1944',
#  'High Fidelity',
#  'Holes',
#  'Hopeless',
#  'How the Grinch Stole Christmas!',
#  'How to Win Friends and Influence People',
#  'Hush, Hush',
#  'I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#  'I Am Number Four',
#  'I Know This Much Is True ',
#  'I Know Why the Caged Bird Sings',
#  'I, Robot',
#  'If I Stay',
#  'If You Give a Mouse a Cookie',
#  'Il nome della rosa',
#  'Im Westen nichts Neues',
#  'In Cold Blood',
#  'In Her Shoes',
#  'In the Woods',
#  'Inferno',
#  'Insurgent',
#  'Interview with the Vampire',
#  'Into Thin Air: A Personal Account of the Mt. Everest Disaster',
#  'Into the Wild',
#  'Is Everyone Hanging Out Without Me? (And Other Concerns)',
#  'Island of the Blue Dolphins',
#  'It',
#  "It's Kind of a Funny Story",
#  'James and the Giant Peach',
#  'Jane Eyre',
#  'John Adams',
#  'Just Listen',
#  'Killing Floor',
#  'La sombra del viento',
#  'Last Sacrifice ',
#  'Le Comte de Monte-Cristo',
#  'Le Petit Prince',
#  "Left Behind:  A Novel of the Earth's Last Days",
#  'Legend',
#  'Les Misérables',
#  'Les Trois Mousquetaires',
#  'Life After Life',
#  'Life of Pi',
#  'Living Dead in Dallas',
#  'Lolita',
#  'Looking for Alaska',
#  'Lord of the Flies ',
#  'Luftslottet som sprängdes',
#  'L’Étranger',
#  'Madame Bovary',
#  'Mansfield Park',
#  'Marked',
#  "Marley & Me: Life and Love with the World's Worst Dog",
#  'Matched',
#  "Maus: A Survivor's Tale : My Father Bleeds History",
#  'Me Before You',
#  'Mere Christianity',
#  'Message in a Bottle',
#  'Middlesex',
#  'Midnight in the Garden of Good and Evil',
#  'Misery',
#  'Miss Peregrine’s Home for Peculiar Children',
#  'Mistborn : The Final Empire',
#  'Moby Dick; or, The Whale',
#  'Mockingjay',
#  'Much Ado About Nothing',
#  "My Sister's Keeper",
#  'Män som hatar kvinnor',
#  'Naked',
#  'Needful Things',
#  'Nesnesitelná lehkost bytí',
#  'Neuromancer',
#  'Never Let Me Go',
#  'Neverwhere',
#  'New Moon (Twilight, #2)',
#  'Nineteen Eighty-Four',
#  'Northern Lights',
#  'Number the Stars',
#  'O Alquimista',
#  'Of Mice and Men ',
#  "Oh, the Places You'll Go!",
#  'Oliver Twist',
#  'On the Road',
#  'One Day',
#  "One Flew Over the Cuckoo's Nest",
#  'One for the Money',
#  'Orphan Train',
#  'Oryx and Crake',
#  'Outlander',
#  'Outliers: The Story of Success',
#  'Pandemonium',
#  'Paper Towns',
#  'Perfect Chemistry',
#  'Pet Sematary',
#  'Peter Pan',
#  'Post-Mortem:  A Mystery Introducing Dr. Kay Scarpetta',
#  'Pretty Little Liars',
#  'Pride and Prejudice',
#  'Prince Caspian: The Return to Narnia',
#  "Quiet: The Power of Introverts in a World that Can't Stop Talking",
#  'Rebecca',
#  'Red Queen',
#  'Reflected in You',
#  'Remember Me?',
#  'Room',
#  'Safe Haven',
#  "Salem's Lot",
#  'Scarlet',
#  'Sense and Sensibility',
#  'Shadow Kiss',
#  'Sharp Objects',
#  "She's Come Undone",
#  'Shiver',
#  'Siddhartha',
#  'Silence ',
#  "Slaughterhouse-Five, or The Children's Crusade: A Duty-Dance with Death ",
#  'Snow Crash',
#  'Snow Flower and the Secret Fan',
#  'Something Borrowed',
#  'Speak',
#  'Speaker for the Dead',
#  'Spirit Bound',
#  'Stardust',
#  'Stargirl',
#  'Station Eleven',
#  'Steve Jobs',
#  'Storm Front',
#  'Stranger in a Strange Land',
#  'Ten Little Niggers',
#  "Tess of the d'Urbervilles: A Pure Woman Faithfully Presented",
#  'The 5th Wave',
#  'The 7 Habits of Highly Effective People',
#  'The Adventures of Huckleberry Finn',
#  'The Adventures of Tom Sawyer',
#  'The Amazing Adventures of Kavalier & Clay',
#  'The Amber Spyglass',
#  'The Angel Experiment',
#  'The Art of Racing in the Rain',
#  'The BFG',
#  'The Bad Beginning',
#  'The Battle of the Labyrinth',
#  'The Bell Jar',
#  'The Book Thief',
#  'The Bourne Identity',
#  'The Boy in the Striped Pyjamas',
#  'The Brief Wondrous Life of Oscar Wao',
#  'The Call of the Wild',
#  'The Casual Vacancy',
#  'The Cat in the Hat',
#  'The Catcher in the Rye',
#  'The Chronicles of Narnia',
#  'The City of Ember',
#  'The Clan of the Cave Bear',
#  'The Colour of Magic',
#  'The Complete Tales of Edgar Allan Poe',
#  'The Crucible',
#  "The Cuckoo's Calling",
#  'The Curious Incident of the Dog in the Night-Time',
#  'The Da Vinci Code',
#  'The Death Cure',
#  'The Devil in the White City: Murder, Magic, and Madness at the Fair that Changed America',
#  'The Dragon Reborn ',
#  'The Elite',
#  'The Eye of the World',
#  'The Fault in Our Stars',
#  'The Firm',
#  'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#  'The Fountainhead',
#  'The Girl on the Train',
#  'The Giver',
#  'The Giving Tree',
#  'The Glass Castle',
#  'The God Delusion',
#  'The God of Small Things',
#  'The Godfather',
#  'The Goldfinch',
#  'The Good Earth',
#  'The Grapes of Wrath',
#  'The Graveyard Book',
#  'The Great Gatsby',
#  'The Green Mile',
#  'The Guardian',
#  'The Guernsey Literary and Potato Peel Pie Society',
#  'The Gunslinger',
#  "The Handmaid's Tale",
#  'The Help',
#  'The Hiding Place',
#  'The Historian',
#  "The Hitchhiker's Guide to the Galaxy",
#  'The Hobbit',
#  'The Hobbit or There and Back Again',
#  'The Host',
#  'The Hunger Games',
#  'The Hunger Games Box Set',
#  'The Hunt for Red October',
#  "The Husband's Secret ",
#  'The Immortal Life of Henrietta Lacks',
#  'The Invention of Wings',
#  'The Joy Luck Club',
#  'The Kitchen House',
#  'The Kite Runner ',
#  'The Language of Flowers',
#  'The Last Lecture',
#  'The Last Olympian',
#  'The Last Song',
#  'The Life and Strange Surprising Adventures of Robinson Crusoe of York, Mariner',
#  'The Light Between Oceans',
#  'The Lightning Thief',
#  'The Lincoln Lawyer ',
#  'The Lion, the Witch and the Wardrobe',
#  'The Lorax',
#  'The Lord of the Rings',
#  'The Lost Hero',
#  'The Lost Symbol',
#  'The Lovely Bones',
#  'The Lucky One',
#  'The Magicians',
#  'The Mark of Athena',
#  'The Martian',
#  'The Maze Runner',
#  'The Name of the Wind',
#  'The Namesake',
#  'The Night Circus',
#  'The Nightingale',
#  "The No. 1 Ladies' Detective Agency ",
#  'The Notebook',
#  'The Ocean at the End of the Lane',
#  'The Old Man and the Sea',
#  "The Omnivore's Dilemma",
#  'The One',
#  'The Other Boleyn Girl',
#  'The Other Hand',
#  'The Outsiders',
#  'The Pact',
#  'The Paris Wife',
#  'The Perks of Being a Wallflower',
#  'The Picture of Dorian Gray',
#  'The Poisonwood Bible',
#  'The Power of Habit',
#  'The Prince of Tides',
#  'The Princess Bride',
#  'The Princess Diaries',
#  'The Prophet',
#  'The Red Pyramid',
#  'The Return of the King',
#  'The Road',
#  'The Rosie Project',
#  'The Scarlet Letter',
#  'The Sea of Monsters',
#  'The Secret',
#  'The Secret Garden',
#  'The Secret History',
#  'The Secret Life of Bees',
#  'The Selection',
#  'The Shack: Where Tragedy Confronts Eternity',
#  'The Shining',
#  'The Silence of the Lambs',
#  'The Sisterhood of the Traveling Pants',
#  'The Son of Neptune ',
#  'The Stand',
#  'The Strange Case of Dr Jekyll and Mr Hyde',
#  'The Subtle Knife',
#  'The Sun Also Rises',
#  'The Tales of Beedle the Bard',
#  'The Tell-Tale Heart',
#  'The Things They Carried',
#  'The Thirteenth Tale',
#  'The Thorn Birds',
#  'The Time Machine',
#  "The Time Traveler's Wife",
#  'The Tipping Point: How Little Things Can Make a Big Difference',
#  "The Titan's Curse",
#  'The Tragedy of Macbeth',
#  'The Tragedy of Othello, The Moor of Venice',
#  'The Tragicall Historie of Hamlet, Prince of Denmark',
#  'The Truth About Forever',
#  'The Two Towers',
#  "The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story",
#  'The Very Hungry Caterpillar',
#  'The Virgin Suicides',
#  'The Voyage of the Dawn Treader',
#  'The Walking Dead, Vol. 1: Days Gone Bye',
#  'The War of the Worlds',
#  'The Way of Kings',
#  "The Wise Man's Fear",
#  'The Witches',
#  'The Wonderful Wizard of Oz',
#  'The World According to Garp',
#  'The horse and his boy',
#  "The magician's nephew",
#  'Their Eyes Were Watching God',
#  'Things Fall Apart',
#  'Thirteen Reasons Why',
#  'Three Cups of Tea ',
#  'Throne of Glass',
#  'Timeline',
#  'Tintenherz',
#  'To Kill a Mockingbird',
#  'Treasure Island',
#  'Tuck Everlasting',
#  'Tuesdays with Morrie',
#  'Twilight',
#  'Twilight: The Complete Illustrated Movie Companion',
#  'Uglies',
#  'Un di Velt Hot Geshvign',
#  'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#  'Under the Dome',
#  'Under the Tuscan Sun',
#  'Untamed: A House of Night Novel',
#  'V for Vendetta',
#  'Voyager',
#  'Wall and Piece',
#  'Watchmen',
#  'Water for Elephants',
#  'Watership Down',
#  'Ways of Seeing',
#  'We Were Liars',
#  'What Alice Forgot',
#  'Where She Went',
#  'Where the Heart Is',
#  'Where the Red Fern Grows',
#  'Where the Sidewalk Ends: The Poems and Drawings of Shel Silverstein',
#  'Where the Wild Things Are',
#  "Where'd You Go, Bernadette",
#  'White Oleander',
#  'Wicked: The Life and Times of the Wicked Witch of the West',
#  'Wild: From Lost to Found on the Pacific Crest Trail ',
#  'Will Grayson, Will Grayson',
#  'Wonder',
#  'World War Z: An Oral History of the Zombie War',
#  'Yes Please',
#  'Zen and the Art of Motorcycle Maintenance',
#  'Анна Каренина',
#  'Братья Карамазовы',
#  'Война и миръ',
#  'Преступление и наказание',
#  'Ὀδύσσεια',
#  '…trotzdem Ja zum Leben sagen: Ein Psychologe erlebt das Konzentrationslager',
#  'ねじまき鳥クロニクル [Nejimakidori kuronikuru]',
#  'デスノート #1 (Desu Nōto) Taikutsu (退屈)',
#  '孫子兵法 [Sūnzi bīngfǎ]']

# %% [markdown]
# ### Column Normalization

# %%
books["normalized"] = books["original_title"].str.replace(' ', '_').str.lower()
books_colors["normalized"] = books_colors["original_title"].str.replace(' ', '_').str.lower()

# %% [markdown]
# ### Saving Data

# %%
#General Data
books.to_csv(r'/Users/karthikrameshbabu/midsScratch/MIDS/w207/BooksFinalProject/MIDS207-Final-Project/data/parsed_data/ultimate.csv', index = False)

#General + Color Data  
books_colors.to_csv(r'/Users/karthikrameshbabu/midsScratch/MIDS/w207/BooksFinalProject/MIDS207-Final-Project/data/parsed_data/books_colors.csv', index = False)

# %%
print(books.shape)
books.head()
# Out:
# (8730, 23)
#    book_id  goodreads_book_id  books_count                      authors  \
# 0        1            2767052          272              Suzanne Collins
# 1        2                  3          491  J.K. Rowling, Mary GrandPré
# 2        3              41865          226              Stephenie Meyer
# 3        4               2657          487                   Harper Lee
# 4        5               4671         1356          F. Scott Fitzgerald
#
#    original_publication_year                            original_title  \
# 0                     2008.0                          The Hunger Games
# 1                     1997.0  Harry Potter and the Philosopher's Stone
# 2                     2005.0                                  Twilight
# 3                     1960.0                     To Kill a Mockingbird
# 4                     1925.0                          The Great Gatsby
#
#                                                title language_code  \
# 0            The Hunger Games (The Hunger Games, #1)           eng
# 1  Harry Potter and the Sorcerer's Stone (Harry P...           eng
# 2                            Twilight (Twilight, #1)         en-US
# 3                              To Kill a Mockingbird           eng
# 4                                   The Great Gatsby           eng
#
#    average_rating  ratings_count  ...  ratings_2  ratings_3  ratings_4  \
# 0            4.34        4780653  ...     127936     560092    1481305
# 1            4.44        4602479  ...     101676     455024    1156318
# 2            3.57        3866839  ...     436802     793319     875073
# 3            4.25        3198671  ...     117415     446835    1001952
# 4            3.89        2683664  ...     197621     606158     936012
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
# 3    1714267  https://images.gr-assets.com/books/1361975680m...
# 4     947718  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#                                             tag_name  \
# 0  fantasy,young adult,fiction,adventure,sci fi f...
# 1  fantasy,young adult,fiction,harry potter,magic...
# 2  fantasy,young adult,fiction,sci fi fantasy,fan...
# 3  young adult,fiction,childhood,classics,english...
# 4  young adult,fiction,classics,english,books,fav...
#
#                                       class_features cluster  \
# 0  Suzanne Collins,fantasy,young adult,fiction,ad...      37
# 1  J.K. Rowling, Mary GrandPré,fantasy,young adul...      20
# 2  Stephenie Meyer,fantasy,young adult,fiction,sc...      29
# 3  Harper Lee,young adult,fiction,childhood,class...       8
# 4  F. Scott Fitzgerald,young adult,fiction,classi...       8
#
#                                  normalized
# 0                          the_hunger_games
# 1  harry_potter_and_the_philosopher's_stone
# 2                                  twilight
# 3                     to_kill_a_mockingbird
# 4                          the_great_gatsby
#
# [5 rows x 23 columns]

# %%
print(books_colors.shape)
books_colors.head()
# Out:
# (6668, 40)
#    Unnamed: 0  index  book_id  goodreads_book_id  best_book_id  work_id  \
# 0           0      0        1            2767052       2767052  2792775
# 1           1      1        2                  3             3  4640799
# 2           2      2        3              41865         41865  3212258
# 3           3      3        4               2657          2657  3275794
# 4           4      4        5               4671          4671   245494
#
#    books_count       isbn        isbn13                      authors  ...  \
# 0          272  439023483  9.780439e+12              Suzanne Collins  ...
# 1          491  439554934  9.780440e+12  J.K. Rowling, Mary GrandPré  ...
# 2          226  316015849  9.780316e+12              Stephenie Meyer  ...
# 3          487   61120081  9.780061e+12                   Harper Lee  ...
# 4         1356  743273567  9.780743e+12          F. Scott Fitzgerald  ...
#
#    cluster  pct_blue pct_light pct_green  pct_yellow   pct_red  pct_magenta  \
# 0        9  0.001276  0.086735  0.000000    0.031888  0.038265     0.000000
# 1        6  0.073980  0.113520  0.002551    0.193878  0.202806     0.008929
# 2        4  0.000000  0.290816  0.000000    0.002551  0.043367     0.000000
# 3        6  0.000000  0.227041  0.001276    0.051020  0.406888     0.000000
# 4        1  0.020408  0.399235  0.000000    0.006378  0.017857     0.000000
#
#    pct_cyan  pct_dark                                normalized
# 0       0.0  0.841837                          the_hunger_games
# 1       0.0  0.404337  harry_potter_and_the_philosopher's_stone
# 2       0.0  0.663265                                  twilight
# 3       0.0  0.313776                     to_kill_a_mockingbird
# 4       0.0  0.556122                          the_great_gatsby
#
# [5 rows x 40 columns]
