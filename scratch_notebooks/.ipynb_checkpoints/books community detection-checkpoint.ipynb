# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
books_comm = pd.read_csv('../data/raw_data/popular_and_similar_books.csv')
books_comm.drop(books_comm.columns[0], axis=1, inplace = True)

# %%
#books_comm['rank'==1]
books_comm.title.value_counts()
# Out:
# ESV Study Bible                                                    10
# Mark of the Lion Trilogy                                           10
# The Indispensable Calvin and Hobbes                                10
# The Stand: Soul Survivors                                          10
# The Complete Calvin and Hobbes                                     10
# It's a Magical World: A Calvin and Hobbes Collection               10
# The Divan                                                          10
# The Lord of the Rings: The Return of the King: Visual Companion    10
# A Voice in the Wind (Mark of the Lion, #1)                         10
# The Calvin and Hobbes Tenth Anniversary Book                       10
# Name: title, dtype: int64

# %%
b1 = books_comm[books_comm['book_id'] == 4410]
b2 = books_comm[books_comm['book_id'] == 1788]
union = pd.concat([b1,b2])
union
# Out:
#     book_id  similar     score  rank  \
# 0      4410      466  0.045232     5
# 22     4410     2101  0.026277     9
# 23     4410     2655  0.056897     4
# 29     4410     3230  0.297297     2
# 33     4410     4229  0.313305     1
# 46     4410     4729  0.027933     7
# 54     4410     5227  0.031477     6
# 56     4410     5268  0.026201    10
# 94     4410     9055  0.079602     3
# 99     4410     9838  0.027650     8
# 2      1788      780  0.270237     1
# 8      1788     1010  0.263158     2
# 31     1788     3628  0.150000     7
# 40     1788     4483  0.230036     3
# 50     1788     5207  0.221024     5
# 59     1788     5580  0.225201     4
# 68     1788     6361  0.193717     6
# 73     1788     6590  0.106832    10
# 78     1788     6920  0.107831     9
# 83     1788     7254  0.137795     8
#
#                                                 title         authors  \
# 0   The Lord of the Rings: The Return of the King:...     Jude Fisher
# ...

# %%
title=[]
similar_title=[]
score=[]
title = b1['title'].to_list()
similar_title = b1['similar_title'].to_list()
score = b1['score'].to_list()
#setting plot size
plt.figure(3,figsize=(12,12)) 
G = nx.Graph()
#adding graph edges with start nodes and weighted edges between them 
for i in range(len(b1)):
    G.add_edge(title[i], similar_title[i], weight=score[i])
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size = 50,  with_labels = True, node_color = 'y')
nx.draw_networkx_edges(G, pos, alpha=.5)
nx.draw_networkx_labels(G,pos, font_size=9,font_family='sans-serif')
# Out:
# {'The Lord of the Rings: The Return of the King: Visual Companion': Text(-0.00595391,-0.02524,'The Lord of the Rings: The Return of the King: Visual Companion'),
#  'The Hobbit: Graphic Novel': Text(-0.54546,0.429076,'The Hobbit: Graphic Novel'),
#  'The Harry Potter Collection 1-4 (Harry Potter, #1-4)': Text(0.601109,0.707352,'The Harry Potter Collection 1-4 (Harry Potter, #1-4)'),
#  "Ender's Game, Volume 1: Battle School (Ender's Saga)": Text(0.48133,-0.494448,"Ender's Game, Volume 1: Battle School (Ender's Saga)"),
#  'The Lord of the Rings: The Art of The Fellowship of the Ring': Text(0.129566,0.205506,'The Lord of the Rings: The Art of The Fellowship of the Ring'),
#  'The Lord of the Rings: Weapons and Warfare': Text(0.0466132,-0.274886,'The Lord of the Rings: Weapons and Warfare'),
#  'Gnomes': Text(0.931653,-0.0153811,'Gnomes'),
# ...

# %%
title=[]
similar_title=[]
score=[]
title = b2['title'].to_list()
similar_title = b2['similar_title'].to_list()
score = b2['score'].to_list()
plt.figure(3,figsize=(10,10)) 
G = nx.Graph()
for i in range(len(b2)):
    G.add_edge(title[i], similar_title[i], weight=score[i])
nx.draw_circular(G, with_labels = True)

# %%
title=[]
similar_title=[]
score=[]
title = books_comm['title'].to_list()
similar_title = books_comm['similar_title'].to_list()
score = books_comm['score'].to_list()

# %%
plt.figure(3,figsize=(12,12)) 
pos = nx.spring_layout(G)
G = nx.Graph()
for i in range(len(books_comm)):
    G.add_edge(title[i], similar_title[i], weight=score[i])
nx.draw_networkx_nodes(G, pos, node_size = 50)#, with_labels = True)
nx.draw_networkx_edges(G, pos, alpha=.5)
nx.draw_networkx_labels(G,pos, font_size=6,font_family='sans-serif')
#plt.legend(title, loc=1)
# Out:
# {'The Lord of the Rings: The Return of the King: Visual Companion': Text(-0.0245672,-0.402111,'The Lord of the Rings: The Return of the King: Visual Companion'),
#  'The Hobbit: Graphic Novel': Text(-0.231975,-0.579713,'The Hobbit: Graphic Novel'),
#  'A Voice in the Wind (Mark of the Lion, #1)': Text(-0.778037,-0.0816835,'A Voice in the Wind (Mark of the Lion, #1)'),
#  'Redeeming Love': Text(-0.874969,0.00660777,'Redeeming Love'),
#  'The Calvin and Hobbes Tenth Anniversary Book': Text(0.22955,-0.795174,'The Calvin and Hobbes Tenth Anniversary Book'),
#  'Calvin and Hobbes': Text(0.202873,-0.897534,'Calvin and Hobbes'),
#  'The Complete Calvin and Hobbes': Text(0.284909,-0.811725,'The Complete Calvin and Hobbes'),
#  "It's a Magical World: A Calvin and Hobbes Collection": Text(0.205492,-0.771503,"It's a Magical World: A Calvin and Hobbes Collection"),
#  'The Indispensable Calvin and Hobbes': Text(0.177609,-0.775362,'The Indispensable Calvin and Hobbes'),
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx


def minard_graph():
    data1 = """\
24.0,54.9,340000,A,1
24.5,55.0,340000,A,1
25.5,54.5,340000,A,1
26.0,54.7,320000,A,1
27.0,54.8,300000,A,1
28.0,54.9,280000,A,1
28.5,55.0,240000,A,1
29.0,55.1,210000,A,1
30.0,55.2,180000,A,1
30.3,55.3,175000,A,1
32.0,54.8,145000,A,1
33.2,54.9,140000,A,1
34.4,55.5,127100,A,1
35.5,55.4,100000,A,1
36.0,55.5,100000,A,1
37.6,55.8,100000,A,1
37.7,55.7,100000,R,1
37.5,55.7,98000,R,1
37.0,55.0,97000,R,1
36.8,55.0,96000,R,1
35.4,55.3,87000,R,1
34.3,55.2,55000,R,1
33.3,54.8,37000,R,1
32.0,54.6,24000,R,1
30.4,54.4,20000,R,1
29.2,54.3,20000,R,1
28.5,54.2,20000,R,1
28.3,54.3,20000,R,1
27.5,54.5,20000,R,1
26.8,54.3,12000,R,1
26.4,54.4,14000,R,1
25.0,54.4,8000,R,1
24.4,54.4,4000,R,1
24.2,54.4,4000,R,1
24.1,54.4,4000,R,1"""
    data2 = """\
24.0,55.1,60000,A,2
24.5,55.2,60000,A,2
25.5,54.7,60000,A,2
26.6,55.7,40000,A,2
27.4,55.6,33000,A,2
28.7,55.5,33000,R,2
29.2,54.2,30000,R,2
28.5,54.1,30000,R,2
28.3,54.2,28000,R,2"""
    data3 = """\
24.0,55.2,22000,A,3
24.5,55.3,22000,A,3
24.6,55.8,6000,A,3
24.6,55.8,6000,R,3
24.2,54.4,6000,R,3
24.1,54.4,6000,R,3"""
    cities = """\
24.0,55.0,Kowno
25.3,54.7,Wilna
26.4,54.4,Smorgoni
26.8,54.3,Moiodexno
27.7,55.2,Gloubokoe
27.6,53.9,Minsk
28.5,54.3,Studienska
28.7,55.5,Polotzk
29.2,54.4,Bobr
30.2,55.3,Witebsk
30.4,54.5,Orscha
30.4,53.9,Mohilow
32.0,54.8,Smolensk
33.2,54.9,Dorogobouge
34.3,55.2,Wixma
34.4,55.5,Chjat
36.0,55.5,Mojaisk
37.6,55.8,Moscou
36.6,55.3,Tarantino
36.5,55.0,Malo-Jarosewii"""

    c = {}
    for line in cities.split("\n"):
        x, y, name = line.split(",")
        c[name] = (float(x), float(y))

    g = []

    for data in [data1, data2, data3]:
        G = nx.Graph()
        i = 0
        G.pos = {}  # location
        G.pop = {}  # size
        last = None
        for line in data.split("\n"):
            x, y, p, r, n = line.split(",")
            G.pos[i] = (float(x), float(y))
            G.pop[i] = int(p)
            if last is None:
                last = i
            else:
                G.add_edge(i, last, **{r: int(n)})
                last = i
            i = i + 1
        g.append(G)

    return g, c


(g, city) = minard_graph()

plt.figure(1, figsize=(11, 5))
plt.clf()
colors = ["b", "g", "r"]
for G in g:
    c = colors.pop(0)
    node_size = [int(G.pop[n] / 300.0) for n in G]
    nx.draw_networkx_edges(G, G.pos, edge_color=c, width=4, alpha=0.5)
    nx.draw_networkx_nodes(G, G.pos, node_size=node_size, node_color=c, alpha=0.5)
    nx.draw_networkx_nodes(G, G.pos, node_size=5, node_color="k")

for c in city:
    x, y = city[c]
    plt.text(x, y + 0.1, c)
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
def minard_graph():
    g = []
    x = 24.0
    y = 52.0
    G = nx.Graph()
    G.pos = {}  # location
    G.pop = {}  # size
    for i in range(len(b)):
        G.pop[i] = float(score[i])
        G.pos[i] = (float(x),float(y))
        x+=2
        y+=2
        G.add_edge(title[i], similar_title[i], weight =score[i])
    g.append(G)
    return g


g = minard_graph()
pos = nx.spring_layout(g)
plt.figure(1, figsize=(11, 5))
plt.clf()
colors = ["b", "g", "r"]
for G in g:
    for n in G:
        print(G[n])
    c = colors.pop(0)
    for i,n in enumerate(G): 
        i=int(i)
        if i<len(G)-1:
            node_size = G.pop[i]
#             nx.draw_networkx_edges(G, pos, edge_color=c, width=4, alpha=0.5)
            nx.draw_networkx_nodes(G, G.pos, node_size=node_size, node_color=c, alpha=0.5)
            nx.draw_networkx_nodes(G, pos, node_size=5, node_color="k")


#plt.show()

# %%
plt.figure(3,figsize=(10,10)) 
G = nx.Graph()
for i in range(len(b)):
    G.add_edge(title[i], similar_title[i], weight =score[i])
#     if score[i]>=.8:
#         G.col[i] = 'r'
#     elif score[i]>=.5 and score[i]<.8:
#         G.col[i] = 'b'
#     else:
#         G.col[i] = 'y'
pos = nx.spring_layout(G)
#nx.draw_circular(G, with_labels = True) 
#for g in G:
    #node_size = [int(g.pop[n] / 300.0) for n in g]
#     c = [g.col[n] for n in g]
nx.draw_networkx_nodes(g, pos, node_size = 50,  with_labels = True)
nx.draw_networkx_edges(g, pos, alpha=.5)
#     nx.draw_networkx_labels(g,pos, font_size=9,font_family='sans-serif')

# unique = [x for i, x in enumerate(title) if i == title.index(x)]
# print(unique)
#plt.legend(unique, loc=1)
#plt.text(x,y+0.1,s='some text', bbox=dict(facecolor='red', alpha=0.5),horizontalalignment='center')
#plt.set_cmap('rainbow')
# plt.show()
